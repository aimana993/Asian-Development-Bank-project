# %%
import pandas as pd
from sqlalchemy import create_engine # для работы с базой
import glob # для поиска файлов

# %%
path = r"C:\Users\AOmarova\Documents\Courses ABD\final project\new\1.final data\fact_table.xlsx" # путь до папки где файл

df = pd.read_excel(path)

df.head(10)
# Out:
#   bank_trans_type                                          bank_name  \
# 0            card                               Premier Bank Limited
# 1            card                            NRB Commercial Bank Ltd
# 2            card                                  Shimanto Bank Ltd
# 3            card  South Bangla Agriculture and Commerce Bank Lim...
# 4            card                                Meghna Bank Limited
# 5            card                              Citizens Bank Limited
# 6            card                                NRB Global Bank Ltd
# 7            card                                 Prime Bank Limited
# 8            card                                 Padma Bank Limited
# 9            card                              National Bank Limited
#
#          cust_name  cust_contact_no          date_sales  \
# 0            priya    8801529462805 2016-04-26 17:13:00
# 1    harpreet kaur    8801985295010 2018-06-11 19:08:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   bank_trans_type  1000000 non-null  object
#  1   bank_name        974410 non-null   object
#  2   cust_name        996060 non-null   object
#  3   cust_contact_no  1000000 non-null  int64
#  4   date_sales       1000000 non-null  datetime64[ns]
#  5   item_name        1000000 non-null  object
#  6   item_type        1000000 non-null  object
#  7   item_country     1000000 non-null  object
#  8   item_supplier    1000000 non-null  object
#  9   store_division   1000000 non-null  object
#  10  store_district   1000000 non-null  object
#  11  store_upazila    1000000 non-null  object
#  12  quantity         1000000 non-null  int64
#  13  unit             996277 non-null   object
#  14  unit_price       1000000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# bank_trans_type        0
# bank_name          25590
# cust_name           3940
# cust_contact_no        0
# date_sales             0
# item_name              0
# item_type              0
# item_country           0
# item_supplier          0
# store_division         0
# store_district         0
# store_upazila          0
# quantity               0
# unit                3723
# unit_price             0
# total_price            0
# dtype: int64

# %%
newdf = df.dropna()

# %%
newdf.isnull().sum()
# Out:
# bank_trans_type    0
# bank_name          0
# cust_name          0
# cust_contact_no    0
# date_sales         0
# item_name          0
# item_type          0
# item_country       0
# item_supplier      0
# store_division     0
# store_district     0
# store_upazila      0
# quantity           0
# unit               0
# unit_price         0
# total_price        0
# dtype: int64

# %%
newdf.describe()
# Out:
#        cust_contact_no                     date_sales       quantity  \
# count     9.669560e+05                         966956  966956.000000
# mean      8.801753e+12  2017-07-20 20:23:02.122991360       5.999480
# min       8.801510e+12            2014-01-20 14:06:00       1.000000
# 25%       8.801631e+12            2015-10-17 20:59:00       3.000000
# 50%       8.801752e+12            2017-07-20 04:30:00       6.000000
# 75%       8.801877e+12            2019-04-19 03:19:00       9.000000
# max       8.802000e+12            2021-01-23 04:38:00      11.000000
# std       1.440753e+08                            NaN       3.161584
#
#          unit_price    total_price
# count  966956.00000  966956.000000
# mean       17.57131     105.413860
# min         6.00000       6.000000
# 25%        13.00000      47.250000
# 50%        16.00000      90.000000
# 75%        20.00000     144.000000
# max        55.00000     605.000000
# std         8.64885      80.887201

# %%
count_dupl = newdf.duplicated().sum()
count_dupl
# Out:
# 0

# %%
import psycopg2

# %%
# загружаем объединенный датафрейм в бд

username = 'postgres' # по умолчанию postgres
password = 'Aiman_arccd25' # ваш пароль

engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/postgres') # создаем соединение

table_name = 'Sales_raw'

newdf.to_sql(table_name, engine, if_exists='append', index=False) # заносим данные в бд

print('данные загрузились')
# Out:
# данные загрузились
